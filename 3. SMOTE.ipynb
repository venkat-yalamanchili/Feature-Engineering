# %% [markdown]
# SMOTE (Synthetic Minority Oversampling Technique)

# %%
from sklearn.datasets import make_classification

# %%
X,y = make_classification(n_samples=1000,n_features=2,n_clusters_per_class=1,
                    n_redundant=0, weights=[0.90],random_state=12)       # x is input, y is target

# %%
import pandas as pd
df1 = pd.DataFrame(X,columns=['f1','f2'])
df2 = pd.DataFrame(y,columns=['target'])
final_df = pd.concat([df1,df2],axis=1)
final_df.head()
# Out:
#          f1        f2  target
# 0 -0.762898 -0.706808       0
# 1 -1.075436 -1.051162       0
# 2 -0.610115 -0.909802       0
# 3 -2.023284 -0.428945       1
# 4 -0.812921 -1.316206       0

# %%
final_df['target'].value_counts()
# Out:
# target
# 0    900
# 1    100
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

plt.scatter(final_df['f1'],final_df['f2'],c=final_df['target'])  #f1 in X axis, f2 in y axis and legend is target

# %%
pip install imblearn
# Out:
# ...
#    ---------------------------------------- 0.0/235.4 kB ? eta -:--:--
#    - -------------------------------------- 10.2/235.4 kB ? eta -:--:--
#    - -------------------------------------- 10.2/235.4 kB ? eta -:--:--
#    --------------- ----------------------- 92.2/235.4 kB 744.7 kB/s eta 0:00:01
#    --------------- ----------------------- 92.2/235.4 kB 744.7 kB/s eta 0:00:01
#    --------------- ----------------------- 92.2/235.4 kB 744.7 kB/s eta 0:00:01
#    --------------- ----------------------- 92.2/235.4 kB 744.7 kB/s eta 0:00:01
#    --------------------------------- ---- 204.8/235.4 kB 655.1 kB/s eta 0:00:01
#    --------------------------------- ---- 204.8/235.4 kB 655.1 kB/s eta 0:00:01
#    -------------------------------------- 235.4/235.4 kB 554.5 kB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from imblearn.over_sampling import SMOTE

# %%
## Transform the dataset using smote
oversample = SMOTE()
X,y = oversample.fit_resample(final_df[['f1','f2']],final_df['target'])

# %%
X.shape   #You can see the total now is 1800 i.e minority also become 900 using SMOTE
# Out:
# (1800, 2)

# %%
y[y==0]
# Out:
# 0      0
# 1      0
# 2      0
# 4      0
# 5      0
#       ..
# 995    0
# 996    0
# 997    0
# 998    0
# 999    0
# Name: target, Length: 900, dtype: int32

# %%
len(y[y==0])
# Out:
# 900

# %%
len(y[y==1])
# Out:
# 900

# %% [markdown]
# Now We will plot the oversampled data points

# %%
df1 = pd.DataFrame(X,columns=['f1','f2'])
df2 = pd.DataFrame(y,columns=['target'])
oversample_df = pd.concat([df1,df2],axis=1)

# %%
plt.scatter(oversample_df['f1'],oversample_df['f2'],c=oversample_df['target'])

# %% [markdown]
# This is amazing the yellow class also has equal no.of of datapoints interpolated using SMOTE
